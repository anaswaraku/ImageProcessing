# %%
import cv2

# %%
def imgcv2(i):
    cv2.imshow("image",i)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

import matplotlib.pyplot as plt
def pltimg(i):
    img = cv2.cvtColor(i, cv2.COLOR_BGR2RGB)# BGR (Blue-Green-Red) to RGB (Red-Green-Blue) format
    plt.imshow(img)
    plt.axis('off') 
    plt.show()

# %%
alpha=0.5
beta = (1.0 - alpha)

# %%
cat=cv2.imread('cat.jpg')
dog=cv2.imread('dog.jpg')

# %%
print('cat shape:',cat.shape,'\ndog shape: ',dog.shape)
# Out:
# cat shape: (360, 540, 3)
# dog shape:  (183, 275, 3)

# %%
cat=cv2.resize(cat,(275,183))

# %%
print('cat shape:',cat.shape,'\ndog shape: ',dog.shape)
# Out:
# cat shape: (183, 275, 3)
# dog shape:  (183, 275, 3)

# %%
dst=cv2.addWeighted(cat,alpha,dog,beta,0.0)

# %%
pltimg(dst)

# %%
catword=cv2.imread('catword.png')
catword.shape
# Out:
# (297, 468, 3)

# %%
cat=cv2.resize(cat,(468,297))

# %%
dst=cv2.addWeighted(cat,alpha,catword,beta,0.0)

# %%
pltimg(dst)
