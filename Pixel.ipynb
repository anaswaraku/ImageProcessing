# %%
import cv2

# %%
img = cv2.imread("myimage.jpg", cv2.IMREAD_COLOR)
cv2.imshow("image",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
print(img)
# Out:
# [[[113  49   1]
#   [114  50   2]
#   [114  49   4]
#   ...
#   [237 220 193]
#   [238 221 194]
#   [238 221 194]]
#
#  [[113  49   1]
#   [114  50   2]
#   [114  49   4]
#   ...
#   [238 221 194]
#   [238 221 194]
#   [238 221 194]]
#
#  [[113  49   1]
#   [114  50   2]
#   [114  49   4]
#   ...
#   [238 221 194]
#   [238 221 194]
#   [238 221 194]]
#
#  ...
#
#  [[ 10 123  65]
#   [  6 128  68]
#   [ 19 124  67]
#   ...
#   [ 33 194 126]
#   [ 26 192 121]
#   [ 27 198 124]]
#
#  [[  8 124  65]
#   [  2 119  62]
#   [ 14 115  60]
#   ...
#   [ 41 206 139]
#   [ 30 199 130]
#   [ 33 205 133]]
#
#  [[  4 120  61]
#   [  0 110  54]
#   [  0  96  42]
#   ...
#   [ 43 209 144]
#   [ 34 202 135]
#   [ 31 202 134]]]

# %%
import matplotlib.pyplot as plt
# Define color channels
colors = ('b', 'g', 'r')  # OpenCV uses BGR format

plt.figure(figsize=(8, 5))
plt.title("Color Histogram")
plt.xlabel("Pixel Intensity")
plt.ylabel("Frequency")

# Compute and plot histograms for each channel
for i, color in enumerate(colors):
    hist = cv2.calcHist([img], [i], None, [256], [0, 256])
    plt.plot(hist, color=color)

plt.xlim([0, 256])
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  # Convert BGR to RGB
gray_img= cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.imshow("image",gray_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
